# %% [markdown]
# # PHÂN TÍCH NỘI DUNG BÀI VIẾT.

# %%
# %pip install matplotlib pandas numpy seaborn wordcloud
# Out:
# Requirement already satisfied: matplotlib in e:\minhhieu\software\python\lib\site-packages (3.7.1)
# Requirement already satisfied: pandas in e:\minhhieu\software\python\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy in e:\minhhieu\software\python\lib\site-packages (1.24.3)
# Requirement already satisfied: seaborn in e:\minhhieu\software\python\lib\site-packages (0.12.2)
# Requirement already satisfied: wordcloud in e:\minhhieu\software\python\lib\site-packages (1.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\minhhieu\software\python\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\minhhieu\software\python\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in e:\minhhieu\software\python\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_full = pd.read_csv('Data/hotwheels_done.csv')
len(df_full)
path = 'Data/hotwheels_done.npy'
post_list = np.load(path,allow_pickle = True)
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      100 non-null    int64
#  1   post_id         100 non-null    int64
#  2   text            100 non-null    object
#  3   time            100 non-null    object
#  4   timestamp       100 non-null    int64
#  5   comments        100 non-null    int64
#  6   shares          100 non-null    int64
#  7   user_id         100 non-null    int64
#  8   comments_full   100 non-null    object
#  9   reactions       100 non-null    object
#  10  reaction_count  100 non-null    int64
# dtypes: int64(7), object(4)
# memory usage: 8.7+ KB

# %%
post_list = post_list.tolist()
post_list
# Out:
# [[663497495969085,
#   'Only ten cars remain but only one car will take the crown!\r\n\r\nTune in this SATURDAY at 9am PST and see which car will be immortalized into a HotWheels die-cast.',
#   '2023-11-09 23:45:33',
#   1699573533,
#   210,
#   364,
#   100069265216767,
#   '[{\'comment_id\': \'1085531565938845\', \'comment_url\': \'https://facebook.com/1085531565938845\', \'commenter_id\': \'100001757861021\', \'commenter_url\': \'https://facebook.com/mikey.brown.338211?eav=Afa3xpPpHL72UkGxYM5RxhfGVEExp2bKHZvFOuVwKszJNLHhEj6jld49EUy5hi-GAhE&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0\', \'commenter_name\': \'Mikey Brown\', \'commenter_meta\': None, \'comment_text\': \'Can’t wait to see ya there ✌️\', \'comment_time\': datetime.datetime(2023, 11, 9, 9, 0), \'comment_image\': \'https://scontent-sin6-4.xx.fbcdn.net/v/t39.30808-6/399029486_6802447256490469_7293078181442293530_n.jpg?stp=cp0_dst-jpg_e15_q65_s180x540&_nc_cat=101&ccb=1-7&_nc_sid=5f2048&efg=eyJpIjoidCJ9&_nc_ohc=KQew9jea0jIAX8YmRSh&_nc_ht=scontent-sin6-4.xx&oh=00_AfAuyC4-F1W47L7FUj720VidVVhrfij41WE_nBIHR-tZMw&oe=6553C36A\', \'comment_reactors\': [{\'name\': \'Sawyer Kayden\', \'link\': \'https://facebook.com/profile.php?id=100082138123979&eav=Afagr0sfpBu8my4n_HmfnWhIlD4_eq5YKD1pE53mhh8_PzwgXmDXsxgzrJGVfaM7Iq8&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Randy Dininger\', \'link\': \'https://facebook.com/profile.php?id=100079222924545&eav=AfYiUdLYVWSXINmmejYXYkU3O8hqa66awHqqSukSOmU8bZ8d3eHucNNeR39AeSHgLsc&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Mario Letters\', \'link\': \'https://facebook.com/lettersone?eav=AfarVGZv9DBsZQduMqAHXV6KLy1CzPi3T7brMtkLp9a8GzKFaDlukdAkeq8GqbZ89G8&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Hot Wheels\', \'link\': \'https://facebook.com/hotwheels?eav=AfZpAIe_Vz6m95r6tls1-Q6H1EM7gz2B2kZEcK6xsXQQMTltWqqD4e1KgGclMSzSUlE&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'
apply.\r\n\r\n💡🎁GIFT-WITH-PURCHASE AWAITS EACH STORE💡\r\n🧡Shopee: FREE 1x Thomas Storage Box with min. purchase of $60 & above on any products.\r\n💙Lazada: FREE 1x Hot Wheels Limited Edition Drawstring Bag with min. purchase of $40 & above on any products.\r\n\r\n🚗🏎️💨 Shop & build tracks, zoom, flip, stunt, crash… all the way with Hot Wheels City, Monster Trucks, and more!🔥\r\n\r\n🎁Don't miss out, add-to-cart the most exciting 11.11 deals now while stocks last!⏰\r\n\r\nSHOP NOW at\r\n🧡https://bit.ly/MattelStore_ShopeeSG\r\n💙https://bit.ly/MattelStore_LazadaSG\r\n\r\n#ShopeeSG #Shopee1111BigSale #Lazada1111 #LazadaSG #MattelSG",
#   '2023-11-08 06:00:47',
#   1699423247,
#   0,
#   1,
#   100069265216767,
#   '[]',
#   "{'like': 9}",
#   9],
#  [662301126088722,
#   'Tune in this Saturday for the Hot Wheels Legends Tour Global Grand Finale and see which car will be chosen to be immortalized into a Hot Wheels 1:64 scale die-cast.\r\n\r\nStreaming live 11.11.2023 at 9am PST on Hot Wheels social channels and MattelCreations.com.',
#   '2023-11-07 17:15:04',
#   1699377304,
#   58,
#   39,
#   100069265216767,
#   '[{\'comment_id\': \'1283224239043193\', \'comment_url\': \'https://facebook.com/1283224239043193\', \'commenter_id\': \'1531710216\', \'commenter_url\': \'https://facebook.com/SeanTaj?eav=AfZbw8CG1GWoo6-qk6imyEE3xncQqbjmetrnJKJO6ILmiHjr3-iujCTj-e0qVrwgWV0&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0\', \'commenter_name\': \'Sean Tajipour\', \'commenter_meta\': \'Top fan\', \'comment_text\': "Can\'t wait!", \'comment_time\': datetime.datetime(2023, 11, 7, 0, 0), \'comment_image\': \'https://scontent-sin6-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfBcTYs98SXp5sJK_iUl5qu_ydTne37-HiS1Cr9-tgm-HA&oe=6575AB39&_nc_sid=7da55a\', \'comment_reactors\': [{\'name\': \'Hot Wheels\', \'link\': \'https://facebook.com/hotwheels?eav=AfYw8LOj1TvXCOtpogs9IspdJdIlUd79NnO6V0ny-3rjDhfmUuDVgU7yJh-Cov6HS_8&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Mirabel Weston\', \'link\': \'https://facebook.com/profile.php?id=61551334165039&eav=AfZAkJvzYU7dzA8CAGrYvm9Ig8go-hvAC9nRSWiXo73jTUysgFlIFadv9RYpPnN0-A4&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Juan Carlos Zamora\', \'link\': \'https://facebook.com/profile.php?id=61550469955683&eav=AfbZsVLaA1jDIAcDd1vG63M8LEkq11QzUVXQ4NL_j87TXMem65mnzueU2gPQpP0XvCU&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Pramoj33\', \'link\': \'https://facebook.com/profile.php?id=61550318797970&eav=AfZ7nuXn1HKFd2zD94oXaNhBJYZoHaZ3ZDJ6sn_XgvVrkVifT8EoI9H1zVWjY3D6aYA&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Tharathep9\', \'link\': \'https://facebook.com/profile.php?id=61550260778905&eav=AfbvcyDFszBmadFDQD6Jc9kRvFUCNlJz-9lZQyeNfAgCUSiNABtyfHXG2zk_5Ia90bM&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'
'comment_time\': datetime.datetime(2023, 11, 3, 0, 0), \'comment_image\': \'https://scontent-xsp1-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a\', \'comment_reactors\': [{\'name\': \'Mirabel Weston\', \'link\': \'https://facebook.com/profile.php?id=61551334165039&eav=AfZFxcsh4tayURqcnDeeg8wKzzwVZk06GKFyhEtlx4US4I9XvCPlsyoGd02nPw4Trig&fref=pb&paipv=0\', \'type\': \'like\'}], \'comment_reactions\': {\'like\': 1}, \'comment_reaction_count\': 1, \'replies\': [{\'comment_id\': \'1036727920801785\', \'comment_url\': \'https://facebook.com/1036727920801785\', \'commenter_id\': \'100069265216767\', \'commenter_url\': \'https://facebook.com/hotwheels?eav=AfbazETISfhgqyVBnNsxzD8yc0i77WA1H45HTr97vQbz7dFrdiZbjsk55D68gvgiQZ4&fref=nf&rc=p&refid=52&__tn__=%7ERR&paipv=0\', \'commenter_name\': \'Hot Wheels\', \'commenter_meta\': \'Author\', \'comment_text\': \'After February 29, 2024, holders of the entire set of 19 cards will receive instructions for claiming a physical die-cast version of the Lamborghini Veneno.\', \'comment_time\': datetime.datetime(2023, 11, 3, 0, 0), \'comment_image\': \'https://scontent-xsp1-1.xx.fbcdn.net/m1/v/t6/An-OzaYGRs8HJMUUdL-Q9pzzUe-6dYQYH0YuulfJGzClIwZB6ubbGwhtChGS8FxnChgEmifrcrhalKyw7ubZeQmjvur00_4Bm3UKlJBnXJyqwKsR.png?ccb=10-5&oh=00_AfDpfA2mY9ZgwIok_BffQrA4fthUAX2RfvNd011YCxripQ&oe=6575C22B&_nc_sid=7da55a\', \'comment_reactors\': [{\'name\': \'Harrison Jones\', \'link\': \'https://facebook.com/harrison.jones.58152559?eav=AfbqWeq0xooXrEojDK3h2iNCPhwd3O_QKyGgWZqngLBf8i8wMXMV4QDQ6nNTLKtVBjg&fref=pb&paipv=0\', \'type\': \'angry\'}, {\'name\': \'Shelby Roach\', \'link\': \'https://facebook.com/Alumni321?eav=AfZcF1IgIsUpSkM1d_lWcvaMkvqtgj8IZuWqHnHwzGFkj7851VRWBj_6c3gfcGrNPjI&fref=pb&paipv=0\', \'type\': \'angry\'}], \'comment_reactions\': {\'angry\': 2}, \'comment_reaction_count\': 2}, {\'comme ...
#   "{'like': 241, 'love': 146, 'haha': 22, 'wow': 5, 'care': 6, 'sad': 1, 'angry': 3}",
#   424],
#  [658407553144746,
#   'You chose it, and we’re making it!\r\n\r\nCovered in Spectraflame dark purple, with an opening hood and detailed engine, the 1972 Nissan Skyline H/T 2000GT-R is the perfect addition to your collection.\r\n\r\nAvailable for pre-order till 11/13 at 9PM PT for Red Line Club members only. https://bit.ly/RLCsELECTIONS1972NissanSkyline',
#   '2023-10-31 16:46:28',
#   1698770788,
#   193,
#   245,
#   100069265216767,
#   "[{'comment_id': '355166443637214', 'comment_url': 'https://facebook.com/355166443637214', 'commenter_id': '100004044873068', 'commenter_url': 'https://facebook.com/Zachary.whyman16?eav=AfY6x7kDkHblU33Dy8hJpTXtJTY6uL59d6YN7Fcj4-L71vaFnUOGSn4N2D003tON2Ds&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Zachary Whyman', 'commenter_meta': 'Top fan', 'comment_text': 'Hot Wheels already preordered it 😁🤭🤭', 'comment_time': datetime.datetime(2023, 11, 3, 0, 0), 'comment_image': 'https://scontent-xsp1-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a', 'comment_reactors': [{'name': 'Hot Wheels', 'link': 'https://facebook.com/hotwheels?eav=AfaTC5lQRtHMJEAyYFVZqHrno284WRPd4tk50PEGy0PEBzFzPFdSrBX9g8C7elm6zfc&fref=pb&paipv=0', 'type': 'like'}, {'name': 'Brittan 55', 'link': 'https://facebook.com/profile.php?id=100095481940889&eav=AfZt6QZnf4yvrFJUJkYgjYkGIjXmyffiOk9XU9YVk4EucsfHTks_lYqmtNQpSIwYR4s&fref=pb&paipv=0', 'type': 'haha'}, {'name': 'Daeng49', 'link': 'https://facebook.com/profile.php?id=61550344029420&eav=AfYVpTFG833v81B2uY8Cv2aACglmGeQe6_9kUj2U3SGA18n57FX81uJE7wmJCCyQ-04&fref=pb&paipv=0', 'type': 'care'}], 'comment_reactions': {'like': 1, 'haha': 1, 'care': 1}, 'comment_reaction_count': 3, 'replies': [{'comment_id': '705738591585432', 'comment_url': 'https://facebook.com/705738591585432', 'commenter_id': '100069265216767', 'commenter_url': 'https://facebook.com/hotwheels?eav=AfbP5x31neNr0I-m75GRvznJ64ZNY99lKAfRxSdPQ-igyNfZA6Rs6QfPhgiRze06xFI&fref=nf&rc=p&refid=52&__tn__=%7ERR&paipv=0', 'commenter_name': 'Hot Wheels', 'commenter_meta': 'Author', 'comment_text': '🔥👊🔥', 'comment_time': datetime.datetime(2023, 11, 3, 0, 0), 'comment_image': 'https://scontent-xsp1-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a', 'comment_reactors': [{'name': 'Zachary Whyman', 'link': 'https://facebook.com/Zachary.whyman16?eav=AfbH9NERbEXtk2S_1Q82XQUAbq7srn25NxJm-zSI2GmpmSWdFxIKQ0vhrmrJg0XQ3pg&fref=pb&paipv=0', 'type': 'like'}], 'comment_reactions': {'like': 1}, 'comment_reaction_count': 1}]}, {'comment_id': '873558411078671', 'comment_url': 'https://facebook.com/873558411078671', 'commenter_id': '100000254524594', 'commenter_url': 'https://facebook.com/catalin.oltean?eav=Afax-hKVEi3MaF-1ig7meQQAZmxoVTGom2Q9B1URQXkljBAggYEtheE38z2w_SpC8LY&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Catalin Oltean', 'commenter_meta': None, 'comment_text': 'pre-order done!', 'comment_time': datetime.datetime(2023, 11, 3, 0, 0), 'comment_image': 'https://scontent-xsp1-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a', 'comment_reactors': [{'name': 'Hot Wheels', 'link': 'https://facebook.com/hotwheels?eav=AfbYOr3ls-94nyRmatCLxeMKBO4phue5pt9OsxYi_XNeNNYLQU4iHuz-Qcxeijjm2-0&fref=pb&paipv=0', 'type': 'like'}], 'comment_reactions': {'like': 1}, 'comment_reaction_count': 1, 'replies': [{'comment_id': '852221016355880', 'comment_url': 'https://facebook.com/852221016355880', 'commenter_id': '100069265216767', 'commenter_url': 'https://facebook.com/hotwheels?eav=AfbP5x31neNr0I-m75GRvznJ64ZNY99lKAfRxSdPQ-igyNfZA6Rs6QfPhgiRze06xFI&fref=nf&rc=p&refid=52&__tn__=%7ERR&paipv=0', 'commenter_name': 'Hot Wheels', 'commenter_meta': 'Author', 'comment_text': 'yasss💥', 'comment_time': datetime.datetime(2023, 11, 3, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None}]}, {'comment_id': '368962029028113', 'comment_url': 'https://facebook.com/368962029028113', 'commenter_id': ' ...
#   "{'like': 1021, 'love': 635, 'haha': 8, 'wow': 13, 'care': 19, 'sad': 1, 'angry': 1}",
#   1698],
#  [657929893192512,
#   'We think it’s time for an off-road rugged adventure. 🏔 Get your hands on this Ford Bronco R when you buy $20 of die-casts at Kroger.',
#   '2023-10-30 20:00:35',
#   1698696035,
#   140,
#   119,
#   100069265216767,
#   '[{\'comment_id\': \'988431672262314\', \'comment_url\': \'https://facebook.com/988431672262314\', \'commenter_id\': \'560332958\', \'commenter_url\': \'https://facebook.com/nic.malby?eav=AfY2ql6C3JWSZBYZkcmrW-WU7TEeim9-LTz83OZ0_ggA9JCwoYLdr1V8VmI9pFT_U48&fref=nf&rc=p&refid=52&__tn__=R&paipv=0\', \'commenter_name\': \'
', \'comment_time\': datetime.datetime(2023, 10, 27, 0, 0), \'comment_image\': None, \'comment_reactors\': [], \'comment_reactions\': None, \'comment_reaction_count\': None}, {\'comment_id\': \'6476831009109859\', \'comment_url\': \'https://facebook.com/6476831009109859\', \'commenter_id\': \'522370362\', \'commenter_url\': \'https://facebook.com/dakota.hof?eav=AfYkhI9EAMGCcu-dZSiEjv5EefccrkgYP83FEkLtY ...
#   "{'like': 717, 'love': 459, 'wow': 12, 'care': 17, 'sad': 1, 'angry': 1}",
#   1207],
#  [1523980458428686,
#   'SUN, NOV 12 AT 12 AM UTC+07\r\nHot Wheels Legends Tour I Global Grand Finale',
#   '2023-10-30 18:54:31',
#   1698692071,
#   6,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 717, 'love': 459, 'wow': 12, 'care': 17, 'sad': 1, 'angry': 1}",
#   76],
#  [705181675003802,
#   'FRI, NOV 3\r\nHot Wheels Legends Tour I Global Semi Finals',
#   '2023-10-30 18:53:02',
#   1698691982,
#   7,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 717, 'love': 459, 'wow': 12, 'care': 17, 'sad': 1, 'angry': 1}",
#   118],
#  [657825409869627,
#   "🏆 Your finalist of the Hawaii stop of the Hot Wheels Legends Tour 🌺🏁🚗\r\n\r\nCheck out this '69 Camaro with a 6.2 LS engine, stock bottom end, custom turbo hot side & cool side (all TIG welded by the owner), and a beastly 92mm turbo. This street-legal small tire car blazes through the quarter mile in just 8.77 seconds. Every detail, from beadrolling the aluminum parts to building the engine and porting the heads, was done by the owner himself. Legends are made, not born, and this Camaro is proof of that! 🚀💨",
#   '2023-10-30 16:38:16',
#   1698683896,
#   4,
#   25,
#   100069265216767,
#   '[{\'comment_id\': \'1699291960580461\', \'comment_url\': \'https://facebook.com/1699291960580461\', \'commenter_id\': \'100070622712230\', \'commenter_url\': \'https://facebook.com/profile.php?id=100070622712230&eav=AfYRN3hS9gMcoZJKC9CjmCg4gSwt6qK7bDah_ilMi_yto6GipqDJ6f6fu379FGe16_Y&fref=nf&rc=p&refid=52&__tn__=R&paipv=0\', \'commenter_name\': \'James Bitts\', \'commenter_meta\': \'Top fan\', \'comment_text\': \'the car looks incredible\', \'comment_time\': datetime.datetime(2023, 10, 27, 0, 0), \'comment_image\': \'https://scontent-sin6-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a\', \'comment_reactors\': [{\'name\': \'James Bitts\', \'link\': \'https://facebook.com/profile.php?id=100070622712230&eav=AfZRoSVchaZrpdQY1OlGzmkZVl_4guYQ0UYn1EfGRTBCySC8q-oL5a0_KsMB3ZjqNrA&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Hot Wheels\', \'link\': \'https://facebook.com/hotwheels?eav=AfZ_J4QtSqPWTncVoSKc3X5M6hB8c7tW_ToF1s7fGalygGs9MsEqy7ZvoxYrIq1p31k&fref=pb&paipv=0\', \'type\': \'like\'}], \'comment_reactions\': {\'like\': 2}, \'comment_reaction_count\': 2, \'replies\': []}, {\'comment_id\': \'1836210620130777\', \'comment_url\': \'https://facebook.com/1836210620130777\', \'commenter_id\': \'61551334165039\', \'commenter_url\': \'https://facebook.com/profile.php?id=61551334165039&eav=AfYl_l9aqkY70RQ2Oa3Dgwj_zysUmgzyTnRlbeHXiiCKkFbxB2a9BNQFX7H2tFujCtQ&fref=nf&rc=p&refid=52&__tn__=R&paipv=0\', \'commenter_name\': \'Mirabel Weston\', \'commenter_meta\': None, \'comment_text\': \'The great fast and max furious car\', \'comment_time\': datetime.datetime(2023, 10, 27, 0, 0), \'comment_image\': None, \'comment_reactors\': [], \'comment_reactions\': None, \'comment_reaction_count\': None, \'replies\': []}, {\'comment_id\': \'1522105955268551\', \'comment_url\': \'https://facebook.com/1522105955268551\', \'commenter_id\': \'100013297425205\', \'commenter_url\': \'https://facebook.com/karey.pasco?eav=AfZ-3eKc0WBj4iO1PcZOKcaaZCr4FjfI9Q41LV7VaelX_fTIUS7lcIuBu3w91gTDCXw&fref=nf&rc=p&refid=52&__tn__=R&paipv=0\', \'commenter_name\': \'
': \'https://facebook.com/profile.php?id=100070622712230&eav=AfbY0Dl33qTFtldxqYDkEUnvUhb6KlMMbEy0Q5oKQXAALcnW5L-cV0uoctq88jVC60U&fref=nf&rc=p&refid=52&__tn__=R&paipv=0\', \'commenter_name\': \'James Bitts\', \'commenter_meta\': \'Top fan\', \'comment_text\': \'the cars look awesome\', \'comment_time\': datetime.datetime(2023, 10, 27, 0, 0), \'comment_image\': \'https://scontent-sin6-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a\', \'comment_reactors\': [{\'name\': \'James Bitts\', \'link\': \'https://facebook.com/profile.php?id=100070622712230&eav=AfbByeAOtz_bJhpG4IoOWqU9zMAMImtiEQtTeibe3tB1a-M1P3AbBV_P-nGgxYE8L-I&fref=pb&paipv=0\', \'type\': \'like\'}, {\'name\': \'Hot Wheels\', \'link\': \'https://facebook.com/hotwheels?eav=AfYcI5iHh4DdbkcSjc2tQcrpAWqFVXTjGQEJ9_ekUECkPhC88AjRRNBOCEa6ONjGY18&fref=pb&paipv=0\', \'type\': \'like\'}], \'comment_reactions\': {\'like\': 2}, \'comment_reaction_count\': 2, \'replies\': [{\'comment_id\': \'364849869227356\', \'comment_url\': \'https://facebook.com/364849869227356\', \'commenter_id\': \'100069265216767\', \'commenter_url\': \'https://facebook.com/hotwheels?eav=AfZF-I-WzwTPMvkofCjdPTAzo2W2OusgJ6UyMLIH4qbPZs3jXZoRZFwZpMnu04zs-\\\\-\\\\Y&fref=nf&rc=p&refid=52&__tn__=%7ERR&paipv=0\', \'commenter_name\': \'Hot Wheels\', \'commenter_meta\': \'Author\', \'comment_text\': \'The coolest 😎\', \'comment_time\': datetime.datetime(2023, 10, 27, 0,  ...
#   "{'like': 329, 'love': 164, 'haha': 23, 'wow': 6, 'care': 7, 'sad': 1, 'angry': 1}",
#   531],
#  [656744359977732,
#   'We’ve finished the final details and the Dirt Meister is set to be inducted into the Hot Wheels Garage of Legends.\r\n\r\nBut before that can take place, the Dirt Meister has to travel from SoCal to the Laguna Seca for its grand unveiling!\r\n\r\nBuckle up and see what happened when we unveiled the build last weekend at the Rennsport Reunion. 💨',
#   '2023-10-28 16:32:40',
#   1698510760,
#   20,
#   25,
#   100069265216767,
#   "[{'comment_id': '798400538639311', 'comment_url': 'https://facebook.com/798400538639311', 'commenter_id': '100004114339247', 'commenter_url': 'https://facebook.com/profile.php?id=100004114339247&eav=AfZe5rZAKSg0gXs132bUXub3zKN_c3OvZ8Fu84J-Etc0Id6kr73SucVkbXLx97ueOmQ&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Heather Dore', 'commenter_meta': None, 'comment_text': 'Looks so cool', 'comment_time': datetime.datetime(2023, 10, 27, 0, 0), 'comment_image': 'https://scontent-sin6-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a', 'comment_reactors': [{'name': 'Hot Wheels', 'link': 'https://facebook.com/hotwheels?eav=AfbjKq7DS09gshNrker8aDvdAbxFzFXSfWTEHuayq5W2pRj6WhstXVZQl3aKzm0fi2Y&fref=pb&paipv=0', 'type': 'like'}], 'comment_reactions': {'like': 1}, 'comment_reaction_count': 1, 'replies': [{'comment_id': '224642087140320', 'comment_url': 'https://facebook.com/224642087140320', 'commenter_id': '100069265216767', 'commenter_url': 'https://facebook.com/hotwheels?eav=AfY3xEltUNjasD8DsbzHqgFFrOpnKoKJiwSLFAYJNEHs03dg2o0ib5nMWO7vufPDv4I&fref=nf&rc=p&refid=52&__tn__=%7ERR&paipv=0', 'commenter_name': 'Hot Wheels', 'commenter_meta': 'Author', 'comment_text': 'Right?! 🔥', 'comment_time': datetime.datetime(2023, 10, 27, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None}]}, {'comment_id': '861656808883609', 'comment_url': 'https://facebook.com/861656808883609', 'commenter_id': '100076580088805', 'commenter_url': 'https://facebook.com/profile.php?id=100076580088805&eav=AfZYjMGxkNbtzg5cO7OQGvOJfGhN4_4Fqd3fH97QIBN2A7zd60tsw2eoARE-I96oUoQ&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Dodge Man', 'commenter_meta': 'Top fan', 'comment_text': 'First 🥇', 'comment_time': datetime.datetime(2023, 10, 27, 0, 0), 'comment_image': 'https://scontent-sin6-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a', 'comment_reactors': [{'name': 'Hot Wheels', 'link': 'https://facebook.com/hotwheels?eav=AfZOzjDPu5MyfBDmPqF-T790NC2FeRHZrOq0_mQpGQGYGKytDXU89FsT7gVP4W8Rw5k&fref=pb&paipv=0', 'type': 'like'}], 'comment_reactions': {'like': 1}, 'comment_reaction_count': 1, 'replies': [{'comment_id': '307799122115956', 'comment_url': 'https://facebook.com/307799122115956', 'commenter_id': '100069265216767', 'commenter_url': 'https://facebook.com/hotwheels?eav=AfY3xEltUNjasD8DsbzHqgFFrOpnKoKJiwSLFAYJNEHs03dg2o0ib5nMWO7vufPDv4I&fref=nf&rc=p&refid=52&__tn__=%7ERR&paipv=0', 'commenter_name': 'Hot Wheels', 'commenter_meta': 'Author', 'comment_text': '🎉🎉', 'comment_time': datetime.datetime(2023, 10, 27, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None}]}, {'comment_id': '6706154536130207', 'comment_url': 'https://facebook.com/6706154536130207', 'commenter_id': '100070622712230', 'commenter_url': 'https://facebook.com/profile.php?id=100070622712230&eav=AfabhYhDsekUwezHb4jOAEk3Su6JfgtfLN-k1TVRfE3iCjAFRA8WWazWTwfaIQutspo&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'James Bitts', 'commenter_meta': 'Top fan', 'comment_text': 'that looks amazing', 'comment_time': datetime.datetime(2023, 10, 27, 0, 0), 'comment_image': 'https://scontent-sin6-1.xx.fbcdn.net/m1/v/t6/An_UvxJXg9tdnLU3Y5qjPi0200MLilhzPXUgxzGjQzUMaNcmjdZA6anyrngvkdub33NZzZhd51fpCAEzNHFhko5aKRFP5fS1w_lKwYrzcNLupv27.png?ccb=10-5&oh=00_AfCq4KZmOWyfxVuYmZLwRsMoaGo2SRrktTqgxYzz0AOhgQ&oe=6575E379&_nc_sid=7da55a', 'comment_reactors': [{'name': 'James Bitts', 'link': 'https://facebook.com/profile.php?id=100070622712230&eav=AfZTFCq1Ez9H4h26F_xoR_AL_KCqJvSuC_r7HZ-UT5iM137iiYN4rnKRnFBl0IJJriM&fref=pb&paipv=0', 'type':  ...
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   220],
#  [656147136704121,
#   'FUTURE ARCHAEOLOGY\r\n\r\nWe paired these two auto enthusiasts to give you a window into the year 3023. Daniel Arsham transformed Hot Wheels cars into eroded artifacts of the future.\r\n\r\nThis is the only time to get your hands on the limited-edition Porsche 930 & Super Rally Case set, the Rodger Dodger, and other collectibles.\r\n\r\nAvailable at 9 AM PT at MattelCreations.com.',
#   '2023-10-27 15:01:29',
#   1698418889,
#   155,
#   93,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   898],
#  [655077650144403,
#   'We sat down with legendary Hot Wheels designer, Larry Wood, as he reflects back on his time on designing the original Rodger Dodger and our newest collaboration with Daniel Arsham.\r\n#HotWheels #MattelCreations #DanielArsham',
#   '2023-10-25 17:22:36',
#   1698254556,
#   70,
#   52,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   402],
#  [653937020258466,
#   '📍NEW YORK\r\nTogether, we’re exploring how legends are made with artist @DanielArsham.\r\nDuring our two-day gallery, fans experienced this collaboration that showcased transformed Hot Wheels objects into eroded artifacts.\r\n\r\nThe Hot Wheels X Daniel Arsham collection is available for purchase October 27 at 9am PT at @mattelcreations.',
#   '2023-10-23 20:38:54',
#   1698093534,
#   91,
#   44,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   439],
#  [653841896934645,
#   'DON’T MISS OUT!\r\n\r\nEnter the Hot Wheels Roadkill Stubby Bob Sweepstakes for a chance to win an autographed Roadkill 4-pack brought to you by @MotorTrend and @RoadkillShow. No purchase necessary, entry period running from 10/23 to 10/29.\r\n\r\nFor more information, visit: https://bit.ly/3s4TQWp',
#   '2023-10-23 16:59:55',
#   1698080395,
#   217,
#   232,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   2300],
#  [651730183812483,
#   'Revving into high gear as the Hot Wheels Legends Tour rolls into the Hot Wheels HQ in El Segundo, CA! 🏁🔥\r\n\r\nFrom jaw-dropping custom cars to the hottest rides in town, the show was nothing short of impressive. The range of vehicles on display was downright stunning, with mini trucks, prototypes, hot rods, and everything in between taking the stage.\r\n\r\nThe epic day culminated as we crowned Wayne Dick and his build “Rampy” as the El Segundo Hot Wheels Legends Tour finalist. 🚗💨🏆',
#   '2023-10-19 22:01:10',
#   1697752870,
#   29,
#   67,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   522],
#  [651627530489415,
# ...
#   '2023-09-10 02:21:49',
#   1694312509,
#   61,
#   95,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   679],
#  [627684489550386,
#   'Give it the greenlight. 🚦\r\n\r\nThe first-ever Hot Wheels Red Line Club Exclusive Crowdfund is now open. Back the project and unlock tiers to build the ultimate collectible.\r\n\r\nCovered in Spectraflame pink, opening doors and even a multi-piece engine, the RLC Exclusive, 1:18 Candy Striper Crowdfund Gasser will make the perfect addition to your collection.\r\n\r\nStarting 9/12, you’ll only have until 10/9 to bring this drag racer to life.\r\n\r\nFor more information, visit: https://bit.ly/RLCGasserCrowdfund.',
#   '2023-09-08 17:41:24',
#   1694194884,
#   449,
#   351,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   2700],
#  [1579976982808778,
#   'SAT, OCT 14\r\nHot Wheels Monster Trucks Live!',
#   '2023-09-07 17:35:36',
#   1694108136,
#   19,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   35],
#  [314865941211571,
#   'SUN, OCT 9\r\nHot Wheels Monster Trucks Live!',
#   '2023-09-07 17:30:56',
#   1694107856,
#   11,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   30],
#  [627058909612944,
#   'Hot Wheels AcceleRacers Virtual Collectibles - 9.21.2023\r\nLearn more: https://bit.ly/HWNFTAcceleRacers',
#   '2023-09-07 16:02:56',
#   1694102576,
#   109,
#   85,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   485],
#  [627048272947341,
#   "🏁🔥 Get ready for a blazing Hot Wheels experience like never before at the Hot Wheels Singapore Die Cast event! 🚗✨\r\nJoin us on September 9th and 10th, 2023, at Great World City for two days of thrilling action! 🌟\r\n\r\n🎁 The first 100 customers with purchases above $100 gets an autograph card signed by Matt Gabe! Don't miss this collector's dream! 🖋️🏎️\r\n\r\n🤩 Meet & Greet Session Alert: Get a chance to meet Matt Gabe, the Hot Wheels Lead Package Designer, in person! 🤝🏁\r\nsave the date and make sure you secure a seat!\r\n\r\n📸 Visit the Hot Wheels photo booth, snap an epic picture, and share it on your IG story for a shot at winning a signed poster by Matt Gabe, Hot Wheels Lead Package Designer! 📸🏆 We're giving away 10 signed posters to lucky winners each day! 🖋️🌟\r\n🚙 Follow these steps to win:\r\n- Pose and Snap a picture of you and friends/family at Hot Wheels Photo Booth\r\n- Share your best picture on Instagram\r\n- Mention/tag @toyspediasg and @korei_sg\r\n- Use hashtag #HotWheelsSG #SingaporeDieCastExpo #HotWheelsSingaporeDieCast\r\n\r\nNot to forget, FREE GIFTS-WITH-PURCHASE awaits!\r\n🎁 FREE 1x Hot Wheels Carry Case with purchase of $30+ worth of Hot Wheels products.\r\n🎁 FREE 1x Hot Wheels Golden Car with purchase of $50+ worth of Hot Wheels products.\r\n\r\n🔥 ENJOY 20% OFF AMAZON PRIME HOT WHEELS STOREWIDE FROM 8 - 17 SEPT 🔥\r\n🔊Do not want any hassle and would like the convenience of items shipped to your doorstep? We got you covered! Simple scan the QR Code & use the promo code PRIMEHOTW upon checkout to enjoy discounts when you spend $60 on Hot Wheels!\r\nShop at (amazon prime hot wheels link)\r\n\r\n🗓️ 9 - 10 September 2023\r\n📍Great World\r\n\r\nDon't miss out on this high-octane event! Mark your calendars and come join us for an unforgettable Hot Wheels experience at Great World. See you there! 🚗👋🏼\r\n\r\n#HotWheels #SportCarSingapore #CarEventSingapore #HotWheelsDieCast #MeetTheDesigners #SnapAndWin #GetYourSignedPoster",
#   '2023-09-07 15:38:04',
#   1694101084,
#   0,
#   6,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   26],
#  [626570872995081,
#   'The Hot Wheels Legends Tour is back and is going GLOBAL for a worldwide ride! Join us on our journey as we hunt for the next Hot Wheels die-cast car.\r\n\r\nFor more information on all upcoming international stops, visit: https://hotwheelslegends.com/',
#   '2023-09-06 18:24:23',
#   1694024663,
#   17,
#   35,
#   100069265216767,
#   "[{'comment_id': '651701473598997', 'comment_url': 'https://facebook.com/651701473598997', 'commenter_id': '100064650461096', 'commenter_url': 'https://facebook.com/rezarxhds?eav=AfYCDdTAB4Kr1Kprqd2K175vPJZJsMIAwBEtBj1_OyutFMk_cfcyR3zd9qEQYcsabtM&fref=nf&rc=p&refid=52&__tn__=%7ER&paipv=0', 'commenter_name': 'Azmatik VS addke', 'commenter_meta': None, 'comment_text': 'massive hopefully New Zealand and 3 locations Auckland ,feilding, and christchurch would be massive', 'comment_time': datetime.datetime(2023, 9, 10, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}]",
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   159],
#  [263686443168109,
#   'SAT, SEP 16\r\nHot Wheels Hispanic Heritage Month Car Show',
#   '2023-09-06 17:22:16',
#   1694020936,
#   5,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   35],
#  [623442589974576,
#   'The Hot Wheels NFT Garage Series 6 officially opens today at 9am PT.\r\n\r\nCollect or trade virtual collectible pieces of the Hot Wheels NFT Garage Series 6 collection, powered by Rarible available at: https://bit.ly/HotWheelsNFTSeries6.',
#   '2023-08-31 14:50:26',
#   1693493426,
#   58,
#   18,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   206],
#  [778271634099387,
#   'SAT, OCT 21\r\nHot Wheels Legends Tour I Hawaii',
#   '2023-08-29 21:18:34',
#   1693343914,
#   18,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   68],
#  [622404876745014,
#   'SET YOUR ALARM. 🚨\r\n\r\nThere’s only 2 ways to get your hands on this years Hot Wheels Legends exclusive die-cast, IRL at any upcoming Legends stop or online at select times.\r\n\r\nGet your hands on the Honda S2000 today at 10am PT: https://bit.ly/LegendsTourShop.',
#   '2023-08-29 16:01:11',
#   1693324871,
#   143,
#   67,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   807],
#  [620890880229747,
#   "Introducing your latest finalist from the Chicago stop of the Hot Wheels Legends Tour! 🏁🔥 This 1988 Chrysler Conquest, codenamed OVERKILL, is more than just a car – it's a statement.\r\n\r\nWith an LS2 heart pumping out 400 horsepower and a custom wide body that's 6 inches wider than stock, this beast was born to dominate both the straightaways and technical twisting turns.\r\n\r\nFrom the track day battles to SEMA's grand stage, it's a never-ending project that's all about pushing limits and leaving the competition in the dust. 💪🚗💨\r\n\r\nMobil 1\r\nWalmart",
#   '2023-08-26 16:31:02',
#   1693067462,
#   117,
#   91,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   679],
#  [619921810326654,
#   'It’s that time!\r\n\r\nIf you got a premium or NFTH, you can also get your hands on an ultra limited-edition Hot Wheels die-cast.\r\n\u2063\r\nFor more information, visit: https://bit.ly/HWNFTVirtualCollectors',
#   '2023-08-24 18:13:45',
#   1692900825,
#   61,
#   47,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   466],
#  [161925596933040,
#   'THU, SEP 28\r\nHot Wheels Legends Tour I Australia & New Zealand (Virtual)',
#   '2023-08-21 18:03:43',
#   1692641023,
#   19,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   111],
#  [618345050484330,
#   'All revved up.\r\n\r\nWith our all-new premium pack type, you’re guaranteed an ultra-rare physical die-cast car. Get yours when the Hot Wheels NFT Garage opens on 8.31.23 at 9AM PT.\r\n\r\nLearn more: https://bit.ly/HotWheelsNFTSeries6',
#   '2023-08-21 17:32:31',
#   1692639151,
#   45,
#   46,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   419],
#  [616236684028500,
#   'The Hot Wheels NFT Garage Series 6 and the Mattel Creations Virtual Market Place, powered by Rarible, open on 8.31.2023.\r\n\r\nLearn more: https://bit.ly/HotWheelsNFTSeries6',
#   '2023-08-17 16:09:59',
#   1692288599,
#   41,
#   31,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   246],
#  [615733467412155,
#   'Get all of your virtual collectibles in one place by transferring your NFT Garage Series 1-3 items to Mattel Creations now until November 17.\r\n\r\nLearn more: https://bit.ly/HWNFTAllInOnePlace',
#   '2023-08-16 16:02:26',
#   1692201746,
#   46,
#   27,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   305],
#  [614594867526015,
#   'X Games California 2023 is in the books! 🛹 See what happened when skateboarding legend Tony Hawk dropped into Hot Wheels.',
#   '2023-08-14 16:10:12',
#   1692029412,
#   19,
#   13,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   213],
#  [928720261946657,
#   "Let's take a closer look at the details from Rally Resilience, the Season 1 winner of Hot Wheels: Ultimate Challenge. 🏎\r\n\r\nThe collectible Nissan Skyline diecast is available for pre-order HERE ➡️ https://bit.ly/HWUCWinnerDiecast.",
#   '2023-08-11 20:49:46',
#   1691786986,
#   65,
#   38,
#   100044260758127,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   220],
#  [613012507684251,
#   'Celebrate the Barbie The Movie with the Hot Wheels Barbie 1956 Corvette® Collector Set.\r\n\r\nAvailable for purchase on 8/15 at MattelCreations.com.',
#   '2023-08-11 17:26:06',
#   1691774766,
#   138,
#   174,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   1100],
#  [612476204404548,
#   'Keep on truckin’.\r\n\r\nWe’re partnering with our friends at MotorTrend and Roadkill to bring you Roadkill’s Stubby Bob in 1:64 scale.\r\n\r\nGet your hands on this die-cast, plus a one-year MotorTrend+ subscription on 8/10 for Red Line Club members and 8/12 for general public.\r\n\r\nFor more information, visit: https://bit.ly/MotortrendHotWheels',
#   '2023-08-10 17:10:04',
#   1691687404,
#   265,
#   294,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   2400],
#  [611569427828559,
#   'ULTIMATE CHALLENGE, ULTIMATE WINNER 🏆\r\n\r\nThe 1995 Nissan Skyline took the crown as the very first winner of Hot Wheels: Ultimate Challenge season one.\r\n\r\nGet your hands on this champion in 1:64 scale for pre-order now at: https://bit.ly/HWUCWinnerDiecast',
#   '2023-08-09 03:00:44',
#   1691550044,
#   599,
#   477,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   3400],
#  [611477427837759,
#   'It all comes down to this. We’ll be crowning a winner on the finale of Hot Wheels: Ultimate Challenge. 🏆 Tune in tonight at 10PM ET on NBC and streaming on Peacock TV.',
#   '2023-08-08 22:36:43',
#   1691534203,
#   108,
#   44,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   910],
#  [610969027888599,
#   'San Diego Comic Con 🤝 Hot Wheels RacerVerse in less than one minute.',
#   '2023-08-07 23:26:19',
#   1691450779,
#   31,
#   98,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   560],
#  [920548882763795,
#   'The Hot Wheels metamorphosis is complete. 🦋',
#   '2023-07-26 19:24:58',
#   1690399498,
#   88,
#   58,
#   100044260758127,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   426],
#  [604287051890130,
#   'This Barbie is a die-cast. ⭐️',
#   '2023-07-26 16:07:49',
#   1690387669,
#   214,
#   278,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   1900],
#  [603922041926631,
#   'Grab your remote because it’s going down tonight!\r\n\r\nJoin Rutledge Wood, Dalal Elsheikh and Hert Eugene Jr. at 10pm ET for an all-new episode of Hot Wheels: Ultimate Challenge on NBC and streaming on Peacock TV.',
#   '2023-07-26 00:40:57',
#   1690332057,
#   94,
#   110,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   958],
#  [603779008607601,
#   'It’s an Italian masterpiece. 🇮🇹\r\n\r\nCovered in Pearlescent blue with authentic Liberty Walk and Lamborghini logos, the Elite 64 LBWK Lamborghini Aventador LP 700-4 is a collector’s dream car.\r\n\r\nAvailable now for pre-order at https://bit.ly/Elite64LBWKLamborghini.',
#   '2023-07-25 16:52:05',
#   1690303925,
#   106,
#   104,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   895],
#  [792621212350353,
#   'SUN, OCT 2\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 22:00:40',
#   1689804040,
#   26,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   61],
#  [2524317091058932,
#   'SAT, OCT 1\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:54:13',
#   1689803653,
#   1,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   39],
#  [950623782882529,
#   'SUN, SEP 25\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:50:18',
#   1689803418,
#   6,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   33],
#  [1013161899811525,
#   'SUN, SEP 25\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:46:55',
#   1689803215,
#   15,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   44],
#  [759814566146846,
#   'SUN, SEP 18\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:43:11',
#   1689802991,
#   12,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   41],
#  [850630479744715,
#   'SUN, SEP 18\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:39:37',
#   1689802777,
#   6,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   23],
#  [236072452645304,
#   'SUN, SEP 11\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:36:06',
#   1689802566,
#   14,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   27],
#  [130770646693712,
#   'SUN, SEP 11\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:30:06',
#   1689802206,
#   5,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   19],
#  [998235587977759,
#   'SUN, SEP 4\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:19:33',
#   1689801573,
#   15,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   20],
#  [300656448999300,
#   'SUN, SEP 4\r\nHot Wheels Monster Trucks Live!',
#   '2023-07-19 21:08:47',
#   1689800927,
#   22,
#   0,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   32],
#  [600244618961040,
#   'Join Hot Wheels, NBC, Rutledge Wood and Dalal Elsheikh tonight at 10PM ET on Threads to live-thread all things Hot Wheels: Ultimate Challenge.',
#   '2023-07-18 21:36:24',
#   1689716184,
#   74,
#   73,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   1000],
#  [599621192356716,
#   "Meet 'Tootsie', a 1985 Mercedes-Benz 300D, who now reigns as the finalist at the Hot Wheels Legends Tour Houston stop! 🎉\r\n\r\nBuilt for both function and fun, this reimagined classic flaunts bold fender flairs, a custom lifted suspension, and an unmissable exhaust exiting through the hood.\r\n\r\nThis yard ornament transformed into rally royalty was a collaboration of 30+ students and one passionate teacher from Dekaney High School's Automotive Technology Program. After countless hours of hard work, Tootsie’s journey is a testament to ingenuity and teamwork. Congratulations to David Almanzan and his incredible team of students. 🙌💥🏎️",
#   '2023-07-17 18:00:08',
#   1689616808,
#   64,
#   94,
#   100069265216767,
#   '[]',
#   "{'like': 173, 'love': 43, 'wow': 1, 'care': 2, 'angry': 1}",
#   1000]]

# %% [markdown]
# ## ================================================================================================================

# %% [markdown]
# ## Sự tương quan giữa số reactions và độ dài bài viết.

# %%
# Biểu đồ tương quan.
df_full['post_length'] = df_full['text'].apply(lambda x : len(str(x)))
length = df_full['post_length']
reactions = df_full['reaction_count']

sns.lmplot(
    data = df_full, 
    y = 'reaction_count',
    x = 'post_length'
)

plt.grid(True, ls = ':', color = 'pink')
plt.xlabel("Length", fontsize = 15)
plt.ylabel("Reaction Count", fontsize = 15)

plt.savefig("Biểu đồ/7.png")

# %% [markdown]
# ## ================================================================================================================

# %% [markdown]
# ## Nội dung bài viết phổ biến nhất.

# %%
# In ra nội dung phổ biến và tạo biểu đồ.
a = df_full['text'].tolist()
print("Có tất cả",len(a),"bài viết:")
res1 = []
res2 = []
for i in a :
  if "Hot Wheels Monster Trucks Live" in i: res1.append(i)
for j in a :
  if "Hot Wheels Legends Tour" in j: res2.append(j)

print(len(res1),"bài viết chưa từ khóa trên 'Hot Wheels Monster Trucks Live'")
print(len(res2),"bài viết chưa từ khóa trên 'Hot Wheels Legends Tour'")

x = ["Hot Wheels Monster Trucks Live", "Hot Wheels Legends Tour"]
y = [len(res1), len(res2)]

plt.bar(x, y, color = 'purple')
plt.title("Common content", fontsize = 20)
plt.savefig("Biểu đồ/8.png")
# Out:
# Có tất cả 100 bài viết:
# 24 bài viết chưa từ khóa trên 'Hot Wheels Monster Trucks Live'
# 18 bài viết chưa từ khóa trên 'Hot Wheels Legends Tour'

# %% [markdown]
# ## =======================================================================================================

# %% [markdown]
# ## Tìm những từ xuất hiện nhiều trong nội dung các bài đăng.

# %%
# Lấy ra nội dung bài viết.
df_full['text']
text = "" 
for i in df_full['text']:
  text = text + i + "\n"

# %%
from wordcloud import WordCloud
from pathlib import Path
import os
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# Biểu đồ stopwords.
texto = text

wordcloud = WordCloud(stopwords = STOPWORDS,
                          background_color = 'white', 
                      max_words = 300,
                      width = 500, height = 300
                         ).generate(texto)
plt.figure(figsize = (40,20))
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

plt.savefig("Biểu đồ/9.png")

# %% [markdown]
# ## ===============================================================================================

# %% [markdown]
# ## Tìm từ quan trọng nhất trong tiêu đề bài viết.

# %% [markdown]
# Để tìm được từ quan trọng nhất trong bài viết, ta cần tính chỉ số TF và IDF, rồi lấy tích của hai giá trị đó. Từ quan trọng nhất sẽ có giá trị lớn nhất.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk import tokenize
import math
from operator import itemgetter
print('The nltk version is {}.'.format(nltk.__version__))
# Out:
# The nltk version is 3.8.1.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from rake_nltk import Rake
r = Rake()
r.extract_keywords_from_text(text)
# r.get_ranked_phrases()
res_cach1=r.get_ranked_phrases_with_scores()
print(res_cach1)
# Out:
# [(103.80812958970854, 'toys ” r ” us 🎁🦒 ✨ free 1x hot wheels carry case'), (103.80812958970854, 'toys ” r ” us 🎁🦒 ✨ free 1x hot wheels carry case'), (87.44232434232434, '✨ free 1x hot wheels limited edition hot wheels drawstring bag'), (87.44232434232434, '✨ free 1x hot wheels limited edition hot wheels drawstring bag'), (84.06878121878121, 'free 1x limited edition hot wheels ™️ drawstring bag *.'), (83.81732434232434, 'hot wheels products .. ✨ free 1x hot wheels collector mail'), (83.81732434232434, 'hot wheels products .. ✨ free 1x hot wheels collector mail'), (72.06878121878123, 'takashimaya 🔥😎 ⚡ free 1x hot wheels carry case'), (70.06878121878121, 'free 1x limited edition hot wheels ™️ collector mail'), (64.56878121878123, 'free 1x hot wheels limited edition drawstring bag'), (59.20687645687646, 'san diego comic con 🤝 hot wheels racerverse'), (57.80589606471959, '16 – 22 oct 🔥🔥 limited time hot wheels deals'), (56.67150453032806, 'toysrussg 🚨 new hot wheels legends tour finalist 🚨 …'), (53.56878121878122, '⚡ free 1x hot wheels collector mail'), (53.06878121878122, '🎁 free 1x hot wheels carry case'), (52.19695582195582, 'hot wheels nft garage series 6 officially opens today'), (51.021162171162175, 'sep 16 hot wheels hispanic heritage month car show'), (50.77380952380952, 'elite 64 series modified ‘ 69 ford mustang'), (47.87354312354313, 'hot wheels barbie 1956 corvette ® collector set'), (46.99908424908425, 'hot wheels x daniel arsham nyc launch event'), (46.67857142857143, '17 sept 🔥 kiddy palace – causeway point'), (46.666666666666664, 'elite 64 land rover defender 90 pickup'), (44.666666666666664, 'elite 64 lbwk lamborghini aventador lp 700'), (44.11640026640026, '🎁 free 1x hot wheels golden car'), (43.91151960784313, '1 oct 🔥 kiddy palace – compass one'), (43.888171196994726, 'el segundo hot wheels legends tour finalist spot'), (43.322847631671166, 'oct 16 hot wheels monster trucks live'), (43.322847631671166, 'oct 16 hot wheels monster trucks live'), (42.290209790209786, 'ever hot wheels red line club exclusive crowdfund'), (42.21713286713287, 'hot wheels challenge accepted southeast asia championship'), (42.21713286713287, 'hot wheels challenge accepted southeast asia championship'), (41.873828023828025, 'sep 18 hot wheels monster trucks live'), (41.873828023828025, 'sep 18 hot wheels monster trucks live'), (41.656180965004495, 'oct 14 hot wheels monster trucks live'), (41.49908424908425, 'hot wheels x daniel arsham collab begins'), (40.873828023828025, 'sep 25 hot wheels monster trucks live'), (40.873828023828025, 'sep 25 hot wheels monster trucks live'), (40.588113738113734, 'sep 4 hot wheels monster trucks live'), (40.588113738113734, 'sep 4 hot wheels monster trucks live'), (40.07284763167115, 'oct 1 hot wheels monster trucks live'), (39.69882802382803, 'nov 6 hot wheels monster trucks live'), (39.69882802382803, 'nov 6 hot wheels monster trucks live'), (39.611519607843135, '9 sept – 1 oct 2023 📌 mark'), (39.611519607843135, '9 sept – 1 oct 2023 📌 mark'), (39.579257888081415, 'oct 2 hot wheels monster trucks live'), (39.49908424908425, 'hot wheels x daniel arsham nyc celebration'), (39.3704666792902, 'oct 23 hot wheels monster trucks live'), (39.3704666792902, 'oct 23 hot wheels monster trucks live'), (39.31827246827247, 'sep 11 hot wheels monster trucks live'), (39.31827246827247, 'sep 11 hot wheels monster trucks live'), (39.281180965004495, 'oct 9 hot wheels monster trucks live'), (39.056180965004486, 'oct 30 hot wheels monster trucks live'), (38.74854312354313, '🏆 winners bring home hot wheels products worth'), (38.74854312354313, '🏆 winners bring home hot wheels products worth'), (36.79293310175663, '2023 hot wheels legends tour uk saw'), (36.31713286713287, 'ultimate hot wheels challenge accepted championship 2023'), (36.31713286713287, 'ultimate hot wheels challenge accepted championship 2023'), (36.05409867909868, 'hot wheels nft garage series 6 collection'), (35.959599768423296, 'biggest hot wheels uk leg ...

# %%
# Lập từ điển từ unique.
def get_unique_numbers(numbers):
    unique = []

    for number in numbers:
        if number in unique:
            continue
        else:
            unique.append(number)
    return unique


a = [i[1] for i in res_cach1]
a.reverse()
a = get_unique_numbers(a)
print(a)
# Out:
# ['10th', '110mph', '15', '2000gt', '26', '29', '31', '40', '420hp', '50', '60', '600', '70', '89', 'accept', 'alarm', 'allows', 'along', 'anticipation', 'anz', 'arrived', 'artist', 'attend', 'authenticity', 'axle', 'backing', 'beadrolling', 'beast', 'becoming', 'bid', 'blurring', 'bone', 'books', 'born', 'brights', 'building', 'builds', 'buy', 'ca', 'calendars', 'careventsingapore', 'cart', 'casts', 'catalyst', 'celebrate', 'celebrating', 'celebrities', 'champion', 'chose', 'chosen', 'clock', 'collect', 'comes', 'compete', 'continuing', 'convenience', 'convert', 'copy', 'countdown', 'crafted', 'create', 'created', 'crown', 'crowning', 'customized', 'cyan', 'dallas', 'date', 'davidson', 'designing', 'determination', 'display', 'dominate', 'done', 'doorstep', 'drive', 'dust', 'earn', 'elite64lbwklamborghini', 'engineering', 'engineers', 'engines', 'enter', 'even', 'everything', 'except', 'exploring', 'fabrication', 'facing', 'fame', 'find', 'finished', 'flip', 'forget', 'function', 'funding', 'getyoursignedposter', 'given', 'got', 'green', 'greenlight', 'guaranteed', 'hands', 'happened', 'harley', 'hassle', 'heads', 'heard', 'hearts', 'heavier', 'highlights', 'hip', 'host', 'hotwheelschallenge
# %%
# Số từ xuất hiện trong tài liệu.
total_words = text.split()
total_word_length = len(total_words)
print(total_word_length)

# Số câu xuất hiện trong tài liệu
total_sentences = tokenize.sent_tokenize(text)
total_sent_len = len(total_sentences)
print(total_sent_len)
# Out:
# 4474
# 263

# %% [markdown]
# Chỉ số TF (Term Frequency) là số đo bằng "số lần xuất hiện của từ đó trong văn bản" / "tổng số từ trong văn bản".

# %%
#Tính TF từng từ.
tf_score = {}
for each_word in total_words:
    each_word = each_word.replace('.','')
    if each_word not in a:
        if each_word in tf_score:
            tf_score[each_word] += 1
        else:
            tf_score[each_word] = 1
print(tf_score)

tf_score.update((x, y/int(total_word_length)) for x, y in tf_score.items())

print(tf_score)
# Out:
# {'Only': 2, 'ten': 1, 'cars': 7, 'remain': 1, 'but': 4, 'only': 7, 'will': 5, 'the': 153, 'crown!': 1, 'Tune': 3, 'in': 33, 'this': 27, 'SATURDAY': 1, 'at': 58, 'PST': 2, 'and': 103, 'which': 2, 'be': 10, 'into': 16, 'a': 75, 'HotWheels': 1, 'die-cast': 12, 'Challengers,': 2, 'let’s': 2, 'full': 1, 'speed': 2, 'ahead': 1, 'Nov!': 1, 'ENJOY': 2, 'UP': 4, 'TO': 4, '70%': 2, 'OFF': 5, 'with': 44, 'Shopee': 2, '1111': 4, 'Big': 3, 'Sale': 2, '&': 24, 'Lazada’s': 1, 'Biggest': 1, 'of': 62, 'The': 28, 'Year!': 1, '🗓️': 3, 'BEST': 1, 'DEALS': 2, 'ONLY': 1, 'on': 62, '🤩': 5, ':': 2, 'EXTRA': 2, '$26': 1, 'Voucher*': 2, 'Lazada': 1, '$22': 1, '*T&Cs': 5, 'apply': 5, '💡🎁GIFT-WITH-PURCHASE': 1, 'AWAITS': 1, 'EACH': 1, 'STORE💡': 1, '🧡Shopee:': 1, 'FREE': 9, '1x': 14, 'Thomas': 1, 'Storage': 1, 'Box': 1, '$60': 2, 'above': 11, 'any': 6, '💙Lazada:': 1, 'Hot': 148, 'Wheels': 138, 'Limited': 5, 'Edition': 5, 'Drawstring': 4, 'Bag': 1, '$40': 3, '🚗🏎️💨': 1, 'Shop': 4, 'tracks,': 1, 'zoom,': 1, 'flip,': 1, 'stunt,': 1, 'crash…': 1, 'all': 12, 'City,': 1, 'Monster': 26, 'Trucks,': 1, 'more!🔥': 1, "🎁Don't": 1, 'out,': 1, 'add-to-cart': 1, 'most': 1, 'exciting': 2, 'deals': 1, 'now': 13, 'while': 3, 'stocks': 4, 'last!⏰': 1, 'SHOP': 1, 'NOW': 3, '🧡https://bitly/MattelStore_ShopeeSG': 1, '💙https://bitly/MattelStore_LazadaSG': 1, '#ShopeeSG': 1, '#Shopee1111BigSale': 1, '#Lazada1111': 1, '#LazadaSG': 1, '#MattelSG': 1, 'Saturday': 3, 'for': 44, 'Legends': 30, 'Tour': 23, 'Global': 6, 'Grand': 3, 'Finale': 4, 'to': 83, '1:64': 6, 'scale': 5, 'Streaming': 1, '11112023': 1, 'social': 1, 'channels': 1, 'MattelCreationscom': 8, 
351363433169424, 'crash…': 0.00022351363433169424, 'all': 0.002682163611980331, 'City,': 0.00022351363433169424, 'Monster': 0.00581135449262405, 'Trucks,': 0.00022351363433169424, 'more!🔥': 0.00022351363433169424, "🎁Don't": 0.00022351363433169424, 'out,': 0.00022351363433169424, 'add-to-cart': 0.00022351363433169424, 'most': 0.00022351363433169424, 'exciting': 0.0004470272686633885, 'deals': 0.00022351363433169424, 'now': 0.002905677246312025, 'while': 0.0006705409029950827, 'stocks': 0.000894054537326777, 'last!⏰': 0.00022351363433169424, 'SHOP': 0.00022351363433169424, 'NOW': 0.0006705409029950827, '🧡https://bitly/MattelStore_ShopeeSG': 0.00022351363433169424, '💙https://bitly/MattelStore_LazadaSG': 0.00022351363433169424, '#ShopeeSG': 0.00022351363433169424, '#Shopee1111BigSale': 0.00022351363433169424, '#Lazada1111': 0.00022351363433169424, '#LazadaSG': 0.00022351363433169424, '#MattelSG': 0.00022351363433169424, 'Saturday': 0.0006705409029950827, 'for': 0.009834599910594547, 'Legends': 0.006705409029950827, 'Tour': 0.005140813589628967, 'Global': 0.0013410818059901655, 'Grand': 0.0006705409029950827, 'Finale': 0.000894054537326777, 'to': 0.018551631649530623, '1:64': 0.0013410818059901655, 'scale': 0.001117568171658471, 'Streaming': 0.00022351363433169424, '11112023': 0.00022351363433169424, 'socia ...

# %% [markdown]
# Chỉ số IDF (Inverse Document Frequency) là chỉ số bằng logarit ( "tổng số văn bản" / "số văn bản chứa từ đó" ).

# %%
def check_sent(word, sentences): 
    final = [all([w in x for w in word]) for x in sentences] 
    sent_len = [sentences[i] for i in range(0, len(final)) if final[i]]
    return int(len(sent_len))


#  Tính IDF cho từng từ.
idf_score = {}
for each_word in total_words:
    each_word = each_word.replace('.','')
    if each_word not in a:
        if each_word in idf_score:
            idf_score[each_word] = check_sent(each_word, total_sentences)
        else:
            idf_score[each_word] = 1

idf_score.update((x, math.log(int(total_sent_len)/y)) for x, y in idf_score.items())

print(idf_score)

# Tính kết quả là tích TF*IDF.
tf_idf_score = {key: tf_score[key] * idf_score.get(key, 0) for key in tf_score.keys()} 
print(tf_idf_score)
# Out:
# {'Only': 2.394100201829819, 'ten': 5.572154032177765, 'cars': 0.4016700371396128, 'remain': 5.572154032177765, 'but': 0.8536551608826699, 'only': 0.7438402948754634, 'will': 0.7846622893957187, 'the': 0.11256851803360554, 'crown!': 5.572154032177765, 'Tune': 0.8185638410713999, 'in': 0.14280840322332372, 'this': 0.16498226071764585, 'SATURDAY': 5.572154032177765, 'at': 0.19225667863730497, 'PST': 1.9612361195335402, 'and': 0.35721827456877897, 'which': 0.8536551608826699, 'be': 0.7201237682581474, 'into': 0.16498226071764585, 'a': 0.1472040146963618, 'HotWheels': 5.572154032177765, 'die-cast': 1.429019305786232, 'Challengers,': 1.8344844138943963, 'let’s': 2.1381668276926185, 'full': 5.572154032177765, 'speed': 0.5885474104694282, 'ahead': 5.572154032177765, 'Nov!': 5.572154032177765, 'ENJOY': 4.879006851617819, 'UP': 2.394100201829819, 'TO': 1.9085923860481182, '70%': 4.473541743509655, 'O
987880566, 'flip,': 0.0012454523987880566, 'stunt,': 0.0012454523987880566, 'crash…': 0.0012454523987880566, 'all': 0.0007479191974607212, 'City,': 0.0012454523987880566, 'Monster': 0.00629670523549089, 'Trucks,': 0.0012454523987880566, 'more!🔥': 0.0012454523987880566, "🎁Don't": 0.0012454523987880566, 'out,': 0.0012454523987880566, 'add-to-cart': 0.0012454523987880566, 'most': 0.0012454523987880566, 'exciting': 0.0009278705725128675, 'deals': 0.0012454523987880566, 'now': 0.0020251312509378563, 'while': 0.0005261481600775941, 'stocks': 0.0008294708386556923, 'last!⏰': 0.0012454523987880566, 'SHOP': 0.0012454523987880566, 'NOW': 0.0015779692941280043, '🧡https://bitly/MattelStore_ShopeeSG': 0.0012454523987880566, '💙https://bitly/MattelStore_LazadaSG': 0.0012454523987880566, '#ShopeeSG': 0.0012454523987880566, '#Shopee1111BigSale': 0.0012454523987880566, '#Lazada1111': 0.0012454523987880566, '#LazadaSG': 0.0012454523987880566, '#MattelSG': 0.0012454523987880566, 'Saturday': 0.0010371942387858396, 'for': 0.006485910246632847, 'Legends': 0.009798481233825122, 'Tour': 0.004297491825439246, 'Global': 0.0026669223429436587, 'Grand': 0.0011405585748345151, 'Finale': 0.0015784457241014257, 'to': 0.0011644060640662375, '1:64': 0.004863089695738647, 'scale': 0.0005210198460853643, 'Streaming': 0.0012454523987880566, '11112023': 0.0012454523987880566, 'social': 0.0012454523987880566, 'channels': 0.0 ...

# %% [markdown]
# Những từ quan trọng sẽ có chỉ số TF-IDF cao.

# %%
# Lấy ra 20 từ quan trọng nhất.
def get_top_n(dict_elem, n):
    result = dict(sorted(dict_elem.items(), key = itemgetter(1), reverse = True)[:n]) 
    return result

from operator import itemgetter
get_top_n(tf_idf_score, 20)
# Out:
# {'Hot': 0.02206037763822566,
#  'Wheels': 0.01731997895736438,
#  '&': 0.012413361613712736,
#  'Live!': 0.011645721862399335,
#  '-': 0.010134572409624457,
#  'Legends': 0.009798481233825122,
#  'SUN,': 0.009666970531357908,
#  'of': 0.00893692926134884,
#  '"R"': 0.008724196426674689,
#  'Trucks': 0.008257764136989629,
#  'and': 0.008223844944252176,
#  '1x': 0.008062115471777567,
#  'with': 0.007005594909232917,
#  '–': 0.006759757823781332,
#  'for': 0.006485910246632847,
#  'Monster': 0.00629670523549089,
#  'OCT': 0.006212822700045606,
#  '🔥Toys': 0.005675920892944827,
#  '✨FREE': 0.005314326490492174,
#  'SEP': 0.005259897647093347}

# %% [markdown]
# ## =============================================================================================================

# %% [markdown]
# ## Thời gian đăng bài phổ biến.

# %%
# Biểu đồ thời gian và thứ tự bài đăng.
df_full['time'] = pd.to_datetime(df_full['time'])
x = df_full['time'].dt.hour
y = df_full['post_id'].index

plt.figure(figsize = (20,6))
plt.xlabel("Hour", fontsize = 15)
plt.ylabel("Post index", fontsize = 15)

colors = np.random.rand(100)

plt.scatter(x, y, s = 20, c = colors, alpha = 1, cmap = 'Spectral')
plt.xticks(x)

plt.savefig("Biểu đồ/10.png")

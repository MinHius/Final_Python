# %% [markdown]
# # PHÂN TÍCH BÌNH LUẬN BÀI VIẾT.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import facebook_scraper

# %%
df_full = pd.read_csv('Data/hotwheels_done.csv')
len(df_full)
path = 'Data/hotwheels_done.npy'
post_list = np.load(path,allow_pickle=True)

# %% [markdown]
# ## =============================================================================================

# %% [markdown]
# ## Trích xuất comment của bài đăng.

# %%
post_list = post_list.tolist()

# %%
# Thuật toán in ra toàn bộ comments và thông tin của người comment theo từng bài viết.
x = len(df_full['comments_full'])
res = []
for i in range(x):
    res.append(df_full['comments_full']) 
res
# Out:
# [0     [{'comment_id': '1085531565938845', 'comment_u...
#  1                                                    []
#  2     [{'comment_id': '1283224239043193', 'comment_u...
#  3     [{'comment_id': '1329690737667516', 'comment_u...
#  4     [{'comment_id': '1848961142226958', 'comment_u...
#                              ...
#  95                                                   []
#  96                                                   []
#  97                                                   []
#  98                                                   []
#  99                                                   []
#  Name: comments_full, Length: 100, dtype: object,
#  0     [{'comment_id': '1085531565938845', 'comment_u...
#  1                                                    []
#  2     [{'comment_id': '1283224239043193', 'comment_u...
#  3     [{'comment_id': '1329690737667516', 'comment_u...
#  4     [{'comment_id': '1848961142226958', 'comment_u...
# ...

# %%
res=[]
for post in post_list:
    if len(post['comments_full']) > 0:
      print(post['comments_full'])
      cmt = '\n'.join([comment['comment_text'] for comment in post['comments_full'] ])
      res.append(cmt)
print(len(res))
print(res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\MINHHIEU\Bài Tập\Đại Học\Sophomore\Python\oh damn\Final_Python\5. Phân tích bình luận.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/e%3A/MINHHIEU/B%C3%A0i%20T%E1%BA%ADp/%C4%90%E1%BA%A1i%20H%E1%BB%8Dc/Sophomore/Python/oh%20damn/Final_Python/5.%20Ph%C3%A2n%20t%C3%ADch%20b%C3%ACnh%20lu%E1%BA%ADn.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> res=[]
#       <a href='vscode-notebook-cell:/e%3A/MINHHIEU/B%C3%A0i%20T%E1%BA%ADp/%C4%90%E1%BA%A1i%20H%E1%BB%8Dc/Sophomore/Python/oh%20damn/Final_Python/5.%20Ph%C3%A2n%20t%C3%ADch%20b%C3%ACnh%20lu%E1%BA%ADn.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> for post in post_list:
# ...

# %% [markdown]
# Trong dữ liệu thu về được qua công cụ facebook scraper, ta nhận thấy có một sự thiếu hụt khá nghiêm trọng liên quan tới dữ liệu comments chi tiết. Nguyên nhân có thể là do facebook đã phát hiện và ngăn chặn không cho công cụ truy cập sâu vào database của facebook. Chính vì lí do này, những gì ta thu được là thông tin bề nổi, và chỉ một phần nhỏ thông tin chi tiết, chỉ được khoảng 1/6 dữ liệu đầy đủ.
#
# Ta có thể đưa ra hai khả năng:
#     1. Công cụ facebook scraper chưa thật sự vượt qua được sự bảo mật thông tin của facebook, với sự thiếu hụt hai thông tin chi tiết về reactions và comments.
